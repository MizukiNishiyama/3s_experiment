# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# CSVファイルを読み込む
df_0 = pd.read_csv('./0.csv')
df_2 = pd.read_csv('./0.2.csv')
df_4 = pd.read_csv('./0.4.csv')
df_6 = pd.read_csv('./0.6.csv')
df_8 = pd.read_csv('./0.8.csv')
df_10 = pd.read_csv('./1.0.csv')
df_12 = pd.read_csv('./1.2.csv')
# 理論的な関数を定義
def func(V_0, R_L, V_DS):
    return (V_0*1000 - V_DS) / R_L

# 理論値を計算
v_theory = np.linspace(0, df_0['V_DS(mV)'].max(), 500)
i_theory = func(20, 20000, v_theory)

# 点と理論曲線をプロット
plt.figure(figsize=(10, 5))
plt.scatter(df_0['V_DS(mV)'], df_0['I(mA)'], color='blue',s=8)
plt.scatter(df_2['V_DS(mV)'], df_2['I(mA)'], color='green', s=8)
plt.scatter(df_4['V_DS(mV)'], df_4['I(mA)'], color='red', s=8)
plt.scatter(df_6['V_DS(mV)'], df_6['I(mA)'], color='blue', s=8)
plt.scatter(df_8['V_DS(mV)'], df_8['I(mA)'], color='green', s=8)
plt.scatter(df_10['V_DS(mV)'], df_10['I(mA)'], color='red', s=8)
plt.scatter(df_12['V_DS(mV)'], df_12['I(mA)'], color='blue', s=8)

# plt.plot(v_theory, i_theory, color='red', label='Theoretical Curve')  # 理論曲線をプロット

## 縦軸を対数にする
# plt.yscale('log')
plt.xlabel('V_ds (mV)')
plt.ylabel('I_D(mA)')
plt.legend()  # 凡例を表示

# グラフを表示
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
